# %% [markdown]
# # Reconstruction parcimonieuse ou compressive sensing

# %% [markdown]
# ## I. Cadre général et première tentative.

# %% [markdown]
# Le but du TP est de montrer que des techniques d'optimisation pour le Machine Learning permettent de récupérer des signaux qui admettent dans une certaine base une représentation parcimonieuse, c'est à dire mettant en jeu un faible nombre de coefficients.
#
# On s'intéresse donc à la reconstruction d'un vecteur $x$ (ici une image codées en niveaux de gris) en utilisant les valeurs de combinaisons aléatoire de certains pixels. Les combinaisons sont représentées par une matrice $\Phi$.
#
# Une première approche consiste à résoudre le problème $$ \min_x \frac{1}{2} ||\Phi x-y||_2^2$$ pour retrouver l'image.
#
# **Question 1 :** Commenter et compléter le code constituant le reste de la section I.

# %%
#
# Installation des librairies
#
#using Pkg
#Pkg.add("ImageMagick")

#
#

#
# Repertoire ou se trouve le fichier cameraman.tif
#
#cd("/home/anas/Desktop/GITS/2A_SN/S8/Optimisation2/TP1") 

#
# Chargement des librairies de traitement d'image
#
using Images, Colors, LinearAlgebra, FFTW


img1 = load("cameraman.tif");    # 
img=convert(Array{Gray},img1);   # 
A = float(convert(Array,img));  # 

tmp=@view img1[:,:]
# Out:
# ┌ Warning: `convert(Array{Gray}, img)` will soon switch to returning an array with non-concrete element type, which adds flexibility but
# │ with great cost to performance. To maintain the current behavior, use `Gray.(img)` instead.
# └ @ ImageCore /Users/badrsajid/.julia/packages/ImageCore/yKxN6/src/deprecations.jl:6
# ┌ Info: It is recommended that you fix this now to avoid breakage when a new version is released and this warning is removed.
# │ Tip: to see all deprecation warnings together with code locations, launch Julia with `--depwarn=yes` and rerun your code.
# └ @ ImageCore /Users/badrsajid/.julia/packages/ImageCore/yKxN6/src/deprecations.jl:7
# 256×256 view(::Array{Gray{N0f8},2}, :, :) with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.624)  …  Gray{N0f8}(0.596)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.604)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.624)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.604)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.6)       Gray{N0f8}(0.592)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.608)  …  Gray{N0f8}(0.6)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.6)       Gray{N0f8}(0.584)
#  Gray{N0f8}(0.624)  Gray{N0f8}(0.624)     Gray{N0f8}(0.576)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.608)     Gray{N0f8}(0.576)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.604)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.604)  Gray{N0f8}(0.616)  …  Gray{N0f8}(0.608)
#  Gray{N0f8}(0.596)  Gray{N0f8}(0.588)     Gray{N0f8}(0.58)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.6)       Gray{N0f8}(0.592)
#  ⋮                                     ⋱  ⋮
#  Gray{N0f8}(0.522)  Gray{N0f8}(0.482)     Gray{N0f8}(0.384)
#  Gray{N0f8}(0.561)  Gray{N0f8}(0.502)  …  Gray{N0f8}(0.467)
#  Gray{N0f8}(0.318)  Gray{N0f8}(0.416)     Gray{N0f8}(0.38)
#  Gray{N0f8}(0.416)  Gray{N0f8}(0.549)     Gray{N0f8}(0.533)
#  Gray{N0f8}(0.537)  Gray{N0f8}(0.478)     Gray{N0f8}(0.376)
#  Gray{N0f8}(0.569)  Gray{N0f8}(0.455)     Gray{N0f8}(0.376)
#  Gray{N0f8}(0.447)  Gray{N0f8}(0.482)  …  Gray{N0f8}(0.392)
#  Gray{N0f8}(0.384)  Gray{N0f8}(0.447)     Gray{N0f8}(0.416)
#  Gray{N0f8}(0.498)  Gray{N0f8}(0.455)     Gray{N0f8}(0.471)
#  Gray{N0f8}(0.447)  Gray{N0f8}(0.518)     Gray{N0f8}(0.447)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.494)     Gray{N0f8}(0.443)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.494)  …  Gray{N0f8}(0.443)

# %%
# Extraction d'une sous-image contrastée
k    = 30;
orig = 60;
Aloc   = A[orig:orig+k-1,orig:orig+k-1];
x   = (Aloc[:]);
n   = length(x);
m   = 500; 
Phi = randn(m,n);

imhsv=colorview(Gray,float(Aloc));
tmp=@view imhsv[:,:]

#
# Fin Extraction
#
# Out:
# 30×30 view(::Array{Gray{Float32},2}, :, :) with eltype Gray{Float32}:
#  Gray{Float32}(0.705882)   …  Gray{Float32}(0.721569)
#  Gray{Float32}(0.698039)      Gray{Float32}(0.713726)
#  Gray{Float32}(0.701961)      Gray{Float32}(0.717647)
#  Gray{Float32}(0.701961)      Gray{Float32}(0.729412)
#  Gray{Float32}(0.705882)      Gray{Float32}(0.717647)
#  Gray{Float32}(0.698039)   …  Gray{Float32}(0.764706)
#  Gray{Float32}(0.709804)      Gray{Float32}(0.588235)
#  Gray{Float32}(0.701961)      Gray{Float32}(0.0705882)
#  Gray{Float32}(0.690196)      Gray{Float32}(0.0588235)
#  Gray{Float32}(0.709804)      Gray{Float32}(0.0627451)
#  Gray{Float32}(0.701961)   …  Gray{Float32}(0.0627451)
#  Gray{Float32}(0.713726)      Gray{Float32}(0.0588235)
#  Gray{Float32}(0.705882)      Gray{Float32}(0.054902)
#  ⋮                         ⋱
#  Gray{Float32}(0.513726)      Gray{Float32}(0.054902)
#  Gray{Float32}(0.0941176)     Gray{Float32}(0.0627451)
#  Gray{Float32}(0.0588235)  …  Gray{Float32}(0.0588235)
#  Gray{Float32}(0.0588235)     Gray{Float32}(0.0627451)
#  Gray{Float32}(0.0627451)     Gray{Float32}(0.054902)
#  Gray{Float32}(0.0666667)     Gray{Float32}(0.0627451)
#  Gray{Float32}(0.0588235)     Gray{Float32}(0.0588235)
#  Gray{Float32}(0.054902)   …  Gray{Float32}(0.0588235)
#  Gray{Float32}(0.0470588)     Gray{Float32}(0.0588235)
#  Gray{Float32}(0.0431373)     Gray{Float32}(0.054902)
#  Gray{Float32}(0.0431373)     Gray{Float32}(0.054902)
#  Gray{Float32}(0.0392157)     Gray{Float32}(0.0588235)

# %% [markdown]
# **Question 2 :** Résoudre le problème de moindres carrés $$\min_x || \Phi x -y ||_2,$$ et afficher le résultat (attention, l'image doit être en niveaux de gris). Que constate-t-on?

# %%
y     = Phi*x ; # Vecteur des "observations" de l'image
## A compléter
x_hat = pinv(Phi)*y
Im = reshape(x_hat,orig -k,orig-k) 
imhsv_res=colorview(Gray,float(Im));
tmp=@view imhsv_res[:,:]
## Fin à compléter
# Out:
# 30×30 view(::Array{Gray{Float64},2}, :, :) with eltype Gray{Float64}:
#  Gray{Float64}(0.281777)    …  Gray{Float64}(0.397978)
#  Gray{Float64}(0.506049)       Gray{Float64}(0.208532)
#  Gray{Float64}(0.247568)       Gray{Float64}(0.109393)
#  Gray{Float64}(0.031732)       Gray{Float64}(0.233023)
#  Gray{Float64}(0.386499)       Gray{Float64}(0.447346)
#  Gray{Float64}(0.649853)    …  Gray{Float64}(0.375221)
#  Gray{Float64}(0.0414165)      Gray{Float64}(0.646926)
#  Gray{Float64}(0.578905)       Gray{Float64}(0.326692)
#  Gray{Float64}(0.616572)       Gray{Float64}(-0.196693)
#  Gray{Float64}(0.391629)       Gray{Float64}(0.175576)
#  Gray{Float64}(0.249919)    …  Gray{Float64}(0.198999)
#  Gray{Float64}(0.464526)       Gray{Float64}(-0.0961406)
#  Gray{Float64}(0.281884)       Gray{Float64}(0.137862)
#  ⋮                          ⋱
#  Gray{Float64}(0.301343)       Gray{Float64}(-0.0434783)
#  Gray{Float64}(0.249591)       Gray{Float64}(0.396503)
#  Gray{Float64}(0.108414)    …  Gray{Float64}(0.24539)
#  Gray{Float64}(-0.0510056)     Gray{Float64}(0.428196)
#  Gray{Float64}(-0.175401)      Gray{Float64}(-0.0272919)
#  Gray{Float64}(0.223939)       Gray{Float64}(0.177269)
#  Gray{Float64}(-0.0632745)     Gray{Float64}(0.199043)
#  Gray{Float64}(0.0506471)   …  Gray{Float64}(0.176006)
#  Gray{Float64}(-0.374626)      Gray{Float64}(0.0317442)
#  Gray{Float64}(0.344112)       Gray{Float64}(-0.0491847)
#  Gray{Float64}(-0.171713)      Gray{Float64}(-0.118445)
#  Gray{Float64}(0.414928)       Gray{Float64}(-0.187826)

# %% [markdown]
# #### II. Compressive sensing

# %% [markdown]
# On désire utiliser à présent la transformation discrète en cosinus pour obtenir une représentaiton parcimonieuse d'une image. Cette transfomation bijective est obtenue avec la fonction `dct`, son inverse s'appelant `idct`.
#
# A partir de la fonction IDCT de Julia, on calcule la matrice  $\Theta = \Phi*\Psi$, avec $\Psi$ la matrice représentative de IDCT dans la base canonique.

# %%
Theta = zeros(m,n);
for ii = 1:n
    ii
    ek = zeros(1,n);
    ek[ii] = 1;
    psi = idct(ek)';
    Theta[:,ii] = Phi*psi;
end

# %% [markdown]
# ### II.1. Utilisation d'un algorithme de sous-gradient

# %% [markdown]
# **Qestion 3 :** Soit $\lambda > 0$ (ici $\lambda=100$). Expliquer l'intérêt de
#  calculer $x_{sg}= \Psi z$ où $z$ résout $$\min_z \frac{1}{2} ||\Phi  \cdot \Psi  \cdot z -y||_2^2+ \lambda ||z||_1.$$
#
# **Qestion 4 :** Justifier la convexité de la fonctionnelle et donner son sous-différentiel.
#
# **Qestion 5 :** Compléter ci-dessous le code de sous-gradient projeté. Vous considèrerez les différents choix de pas $\alpha_i$ vus en cours, et trouverez des réglages permettant d'obtenir un bon rendu visuel. On pourra se rappeler du fait que la solution de norme minimale a une norme inférieure à dix.

# %%
z = zeros(k^2,1); i=0; lambda=1e2;
choix_pas = 1; # 1 cas a, 2 cas b, 3 cas c
while i <= 10000
    i = i + 1; 
    ## A compléter
    temp = z
    gh = ((Theta')*(Theta*z-y)+lambda*sign.(z))
    z = temp - (1/(100*i))*gh/norm(gh)
    ## fin à compléter
end

# %% [markdown]
# **Question 6 :** Expliquer le code suivant et conclure sur l'utilisation du sous-gradient

# %%
function my_function(n,k,z)
    x2 = zeros(n,1);
    for ii = 1:n
        ii
        ek = zeros(1,n);
        ek[ii] = 1;
        psi = idct(ek)';
        x2 = x2+psi*z[ii];
    end
    x2 = reshape(x2,k,k);
    x2 = 1/(maximum(x2).-minimum(x2))*(x2.-minimum(x2));
    return x2
end
#
x2 = my_function(n,k,z);
imhsv = colorview(Gray, float(x2));
tmp=@view imhsv[:,:]
# Out:
# 30×30 view(reinterpret(Gray{Float64}, ::Array{Float64,2}), :, :) with eltype Gray{Float64}:
#  Gray{Float64}(0.692063)  Gray{Float64}(0.629182)  …  Gray{Float64}(0.776539)
#  Gray{Float64}(0.67636)   Gray{Float64}(0.777841)     Gray{Float64}(0.619065)
#  Gray{Float64}(0.516912)  Gray{Float64}(0.623872)     Gray{Float64}(0.602197)
#  Gray{Float64}(0.641354)  Gray{Float64}(0.828881)     Gray{Float64}(0.584889)
#  Gray{Float64}(0.68502)   Gray{Float64}(0.739267)     Gray{Float64}(0.552976)
#  Gray{Float64}(0.900632)  Gray{Float64}(0.641505)  …  Gray{Float64}(0.660701)
#  Gray{Float64}(0.453394)  Gray{Float64}(0.879379)     Gray{Float64}(0.953922)
#  Gray{Float64}(0.632495)  Gray{Float64}(0.845305)     Gray{Float64}(0.695107)
#  Gray{Float64}(0.862593)  Gray{Float64}(0.88251)      Gray{Float64}(0.43144)
#  Gray{Float64}(0.775551)  Gray{Float64}(0.651824)     Gray{Float64}(0.694067)
#  Gray{Float64}(0.519973)  Gray{Float64}(0.737732)  …  Gray{Float64}(0.440636)
#  Gray{Float64}(0.730574)  Gray{Float64}(0.504098)     Gray{Float64}(0.543209)
#  Gray{Float64}(0.738976)  Gray{Float64}(0.764879)     Gray{Float64}(0.467853)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.753615)  Gray{Float64}(0.464788)     Gray{Float64}(0.208823)
#  Gray{Float64}(0.568391)  Gray{Float64}(0.694887)     Gray{Float64}(0.600056)
#  Gray{Float64}(0.696453)  Gray{Float64}(0.504557)  …  Gray{Float64}(0.588043)
#  Gray{Float64}(0.590124)  Gray{Float64}(0.30209)      Gray{Float64}(0.679831)
#  Gray{Float64}(0.460404)  Gray{Float64}(0.314332)     Gray{Float64}(0.593216)
#  Gray{Float64}(0.696446)  Gray{Float64}(0.440679)     Gray{Float64}(0.478367)
#  Gray{Float64}(0.305357)  Gray{Float64}(0.345344)     Gray{Float64}(0.464355)
#  Gray{Float64}(0.345455)  Gray{Float64}(0.197721)  …  Gray{Float64}(0.665848)
#  Gray{Float64}(0.388838)  Gray{Float64}(0.411921)     Gray{Float64}(0.263375)
#  Gray{Float64}(0.705944)  Gray{Float64}(0.524573)     Gray{Float64}(0.466651)
#  Gray{Float64}(0.32313)   Gray{Float64}(0.533226)     Gray{Float64}(0.415178)
#  Gray{Float64}(0.533055)  Gray{Float64}(0.433788)     Gray{Float64}(0.498303)

# %% [markdown]
# # II.2. Utilisation d'un algorithme de sous-gradient projeté

# %% [markdown]
# **Question 7 :**  Expliquer l'intérêt de
#  calculer $x_{sgp}= \Psi z$ où $z$ résout $$\min_{\Phi  \cdot \Psi  \cdot z =y}  ||z||_1.$$

# %% [markdown]
# **Question 8 :** Rappeler la formule de la projection sur le convexe $\{z, \Phi  \cdot \Psi  \cdot z =y \}$ vue en cours.

# %% [markdown]
# **Question 9 :** Résoudre ce problème par l'algorithme de sous-gradient projeté et finaliser le calcul de la solution.

# %%
z = zeros(k^2,1); 

i=0;
choix_pas = 1; # 1 cas a, 2 cas b, 3 cas c

##Initialisation (possible)
## A compléter

z = Theta\y

pinvtheta = pinv(Theta*Theta')
## Fin à compléter

while i <= 1000
    i = i + 1; 
    ## A compléter
    temp = z
    gh = sign.(z)
    z_temp = temp - (1/(100*i))*gh/norm(gh)
    
    # Projection de z sur l'espace.
    z = z_temp - (Theta)'*pinvtheta*(Theta*z_temp-y)
    
    ## Fin à compléter
end

# %%
x3 = my_function(n,k,z);
imhsv = colorview(Gray,float(x3));
tmp =@view imhsv[:,:]
# Out:
# 30×30 view(reinterpret(Gray{Float64}, ::Array{Float64,2}), :, :) with eltype Gray{Float64}:
#  Gray{Float64}(0.621916)  …  Gray{Float64}(0.703255)
#  Gray{Float64}(0.778371)     Gray{Float64}(0.572934)
#  Gray{Float64}(0.598902)     Gray{Float64}(0.503556)
#  Gray{Float64}(0.450232)     Gray{Float64}(0.589851)
#  Gray{Float64}(0.696595)     Gray{Float64}(0.737371)
#  Gray{Float64}(0.878078)  …  Gray{Float64}(0.687273)
#  Gray{Float64}(0.455359)     Gray{Float64}(0.875738)
#  Gray{Float64}(0.829804)     Gray{Float64}(0.653321)
#  Gray{Float64}(0.855578)     Gray{Float64}(0.290868)
#  Gray{Float64}(0.698724)     Gray{Float64}(0.548138)
#  Gray{Float64}(0.600958)  …  Gray{Float64}(0.563538)
#  Gray{Float64}(0.749041)     Gray{Float64}(0.358481)
#  Gray{Float64}(0.622915)     Gray{Float64}(0.521996)
#  ⋮                        ⋱
#  Gray{Float64}(0.635838)     Gray{Float64}(0.395761)
#  Gray{Float64}(0.599779)     Gray{Float64}(0.701105)
#  Gray{Float64}(0.502037)  …  Gray{Float64}(0.596598)
#  Gray{Float64}(0.391031)     Gray{Float64}(0.723382)
#  Gray{Float64}(0.304809)     Gray{Float64}(0.405853)
#  Gray{Float64}(0.57951)      Gray{Float64}(0.548548)
#  Gray{Float64}(0.382257)     Gray{Float64}(0.564156)
#  Gray{Float64}(0.460855)  …  Gray{Float64}(0.546557)
#  Gray{Float64}(0.166348)     Gray{Float64}(0.44781)
#  Gray{Float64}(0.664375)     Gray{Float64}(0.3909)
#  Gray{Float64}(0.308434)     Gray{Float64}(0.344135)
#  Gray{Float64}(0.714155)     Gray{Float64}(0.296147)
